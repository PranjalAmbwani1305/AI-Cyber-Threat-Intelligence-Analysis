# %%
# !pip install pymupdf
# Out:
# Collecting pymupdf
#   Downloading pymupdf-1.26.4-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.26.4-cp39-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 64.4 MB/s eta 0:00:00
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.26.4

# %%
import pymupdf

def extract_text_from_pdf(pdf_path):
    text = ""
    doc = pymupdf.open(pdf_path)
    for page in doc:
      text += page.get_text(sort=True)
    return text

# %%
text = extract_text_from_pdf("Aperture Labs Report.pdf")
print(text)
# Out:
#      Aperture Labs
#
#      Mid-Year Cybersecurity Threat Brief: 2025
#
#         Publication Date: July 20, 2025
#        Reporting Period: January 1, 2025 – June 30, 2025
#         Distribution: Internal - Security Stakeholders
#
#       Table of Contents
#
#          1. Executive Summary
#
#          2. Key Threat Intelligence Findings
#
#          3. Adversary Focus Areas & Observed Campaigns
#
#               Adversary Spotlight: Nation-State Espionage Targeting AI Research
#
#             The R&D Environment as an Attack Vector
#
#               Increased Targeting of Linux Systems
#
#          4. Mid-Year Intrusion Analysis (H1 2025)
#
#                 Intrusion Overview
#
#             Top Initial Access Vectors for Aperture Labs
#
#              Observed Adversary Techniques: "Living Off the Land"
#
#          5. Key Vulnerabilities & Exposures
#
#              Unpatched Open-Source Libraries
#
#                  Insufficient Identity and Access Management
#
#          6. Strategic Recommendations
#
#              Harden the R&D Environment with Zero Trust Principles
#
#              Implement a Robust Vulnerability Management Program
#
#              Enhance Detection Capabilities for Non-Windows Environments
#
#          7. Appendix: Data Sources & Methodology
#
#
#
#
#
# Untitled                                                                                                                                                                             1       1. Executive Summary
#
#        During the first half of 2025, Aperture Labs became a high-value target for
#         sophisticated threat actors, particularly nation-state groups focused on intellectual
#        property theft and corporate espionage. Adversaries have demonstrated a deep
#        understanding of our R&D environment, leveraging our collaborative culture and
#        complex toolchains to their advantage.
#
#       The most significant trend is a sharp increase in targeted attacks from
#
#        China-nexus adversaries, whose activity against the technology sector surged
#       150%. These groups are specifically targeting our proprietary AI model data and
#         IoT hardware schematics. Rather than deploying disruptive ransomware, these
#         actors prioritize stealth, using "living off the land" techniques to remain
#        undetected for extended periods. In fact,
#
#      79% of all security detections within our network were malware-free, indicating
#        a heavy reliance on abusing built-in system tools and valid credentials to achieve
#          their objectives.
#
#       The primary point of entry was the exploitation of vulnerabilities in our public-
#        facing R&D applications and APIs. Furthermore, compromised developer
#         credentials were a contributing factor in over 40% of severe incidents, often due
#         to a lack of multi-factor authentication (MFA) on critical platforms. This report
#         details these trends and provides actionable recommendations to harden our
#        defenses, improve visibility into our unique R&D environment, and better protect
#        our critical intellectual property.
#
#       2. Key Threat Intelligence Findings
#
#            Nation-State Targeting: Activity from China-nexus threat actors targeting our
#            sector increased by 150% compared to the previous year, with a focus on
#             intelligence collection.
#
#            Application Exploits Dominate: The exploitation of public-facing web
#             applications and APIs was the top initial access vector, accounting for 39% of
#                all intrusions.
#
#            "Living Off the Land" is Prevalent: A significant majority of attacks were
#            malware-free. Adversaries relied on hands-on-keyboard techniques, abusing
#
#
#
#
#
# Untitled                                                                                                                   2            legitimate tools like PowerShell and SSH to evade detection.
#
#           Linux Threats on the Rise: We observed a substantial increase in malicious
#          code and activity targeting our Linux-based development servers, a trend that
#               is becoming more common globally.
#
#            Credential Compromise is a Critical Factor: Abuse of valid accounts was a
#            top technique for initial access, persistence, and defense evasion. The lack of
#         MFA remains a significant contributing factor in
#
#        25% of these cases.
#
#       3. Adversary Focus Areas & Observed Campaigns
#
#      Adversary Spotlight: Nation-State Espionage Targeting AI
#      Research
#
#        Throughout H1 2025, our threat intelligence team identified multiple campaigns
#         attributed to China-nexus adversaries targeting our AI research divisions. These
#        groups, including newly identified specialized actors like
#
#       VAULT PANDA, are focused on exploiting web-facing applications to gain initial
#        access and exfiltrate data related to our large language models (LLMs) and neural
#        network architectures. Their tactics are increasingly stealthy, making use of
#       compromised network appliances to hide their origins and using a mix of unique
#       and publicly available tools to navigate our network.
#
#      The R&D Environment as an Attack Vector
#
#       Our open and collaborative R&D environment presents a unique attack surface.
#      We have seen adversaries leverage this by:
#
#            Targeting Open Source Software: Following a concerning industry trend,
#             attackers have targeted our software supply chain by compromising open-
#           source libraries used in our projects. They attempt to insert backdoors into our
#             applications, a tactic that has affected other high-profile open-source
#             projects.
#
#           Abusing Developer Tools: Threat actors abuse legitimate developer tools,
#           such as Visual Studio Code tunneling features, to create covert channels for
#         command and control or data exfiltration.
#
#
#
#
# Untitled                                                                                                                 3     Increased Targeting of Linux Systems
#
#       As our development infrastructure is heavily reliant on Linux, it has become a focal
#         point for adversaries. The emergence of sophisticated Linux threats like the
#
#        Linux.Slapper worm in recent years shows that malicious code writers have
#        increased their familiarity with the Linux operating system. In Q2 2025, we saw a
#          rise in custom ELF binaries and PowerShell scripts executed on our Linux servers,
#        designed for credential harvesting and establishing long-term persistence.
#
#       4. Mid-Year Intrusion Analysis (H1 2025)
#
#       Intrusion Overview
#
#        While the total volume of alerts was slightly lower than in H2 2024, the severity
#       and targeted nature of attacks increased. This indicates a shift from
#         opportunistic, widespread scans to focused intrusion attempts by motivated
#         adversaries. Our Security Operations Center (SOC) escalated 21% fewer events
#          overall, but the proportion of "critical" events (requiring immediate remediation)
#        rose by 15%.
#
#      Top Initial Access Vectors for Aperture Labs
#
#           Software/API Vulnerabilities: 39%
#
#            Phishing: 23%
#
#            Previously Compromised Credentials: 16%
#
#           Brute Force: 13%
#
#           Other (including Insider Threat): 9%
#
#      Observed Adversary Techniques: "Living Off the Land"
#
#        Adversaries are actively trying to blend in with normal administrative activity. The
#       most frequently observed "living off the land" techniques are listed below.
#
#                                                                   Prevalence of Observed
#         MITRE ATT&CK® Technique        Tactic
#                                                                 Techniques
#
#            T1059 - Command and Scripting
#                                           Execution             61%
#            Interpreter
#
#
#
#
#
# Untitled                                                                                                            4                                                             Initial Access, Defense
#            T1078 - Valid Accounts                            41%
#                                          Evasion
#
#            T1021 - Remote Services           Lateral Movement      86%
#
#           T1003 - OS Credential Dumping   Credential Access      44%
#
#        Export to Sheets
#
#       5. Key Vulnerabilities & Exposures
#
#          Unpatched Open-Source Libraries: Analysis of our code repositories revealed
#             that multiple active projects rely on open-source libraries with known, high-
#             severity vulnerabilities. This aligns with the broader threat of attackers
#             targeting the software supply chain.
#
#             Insufficient Identity and Access Management: A lack of strictly enforced
#         MFA on developer-focused platforms like GitHub, VPNs, and SSH gateways
#          was the root cause of several intrusions. Additionally, overly permissive IAM
#             roles in our cloud environments granted attackers excessive access after
#           compromising a single account.
#
#       6. Strategic Recommendations
#
#        1. Harden the R&D Environment with Zero Trust Principles
#
#            Verify Everything: Consistently authenticate and authorize every user and
#            device before granting access to our code repositories and development
#             servers.
#
#           Enforce Least Privilege: Drastically reduce the permissions granted to
#            developer accounts and service principals, particularly in production and
#            cloud environments. Access should be temporary and just-in-time wherever
#             possible.
#
#          Segment Developer Networks: Isolate critical R&D networks from the general
#            corporate network to contain breaches and prevent lateral movement.
#
#       2. Implement a Robust Vulnerability Management Program
#
#
#
#
#
# Untitled                                                                                                                   5             Prioritize with an Adversary-Centric Approach: Move beyond CVSS scores
#          and prioritize patching vulnerabilities that are actively being exploited by
#             threat actors targeting our sector and technologies.
#
#          Automate Code Scanning: Integrate Software Composition Analysis (SCA)
#          and Static Application Security Testing (SAST) tools directly into our CI/CD
#             pipelines to detect vulnerabilities in open-source libraries and custom code
#            before deployment.
#
#       3. Enhance Detection Capabilities for Non-Windows
#      Environments
#
#           Improve Linux Logging: Ensure all Linux development servers have
#           comprehensive logging enabled and that logs are centrally ingested into our
#          SIEM for correlation and analysis.
#
#           Deploy Linux EDR: Expand our Endpoint Detection and Response (EDR)
#             solution to cover 100% of our Linux servers to better detect the abuse of
#             legitimate system tools and other "living off the land" techniques.
#
#        7. Appendix: Data Sources & Methodology
#
#       The analysis in this brief is based on data collected from Aperture Labs' internal
#         security telemetry sources. This includes, but is not limited to, our Endpoint
#        Detection and Response (EDR) platform, network intrusion detection systems
#         (IDS), firewall logs, cloud security posture management (CSPM) tools, and logs
#        from our source code management platforms. All security events are correlated
#       and validated by our Security Operations Center (SOC) analysts to determine
#          intent, severity, and impact. The MITRE ATT&CK® framework is used as the
#        standard for classifying adversary techniques
#
#
#
#
#
# Untitled                                                                                                                 6

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline
from collections import defaultdict

def extract_cti_entities(pdf_path):
    model_name = "CyberPeace-Institute/SecureBERT-NER"
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForTokenClassification.from_pretrained(model_name)

    nlp = pipeline("ner", model=model, tokenizer=tokenizer, aggregation_strategy="simple")

    text = extract_text_from_pdf(pdf_path)
    entities = nlp(text)

    grouped_entities = defaultdict(list)
    for ent in entities:
      grouped_entities[ent['entity_group']].append(ent['word'])

    results = []
    for entity_type, words in grouped_entities.items():
      results.append(f"{entity_type}: {', '.join(words)}")
    return results


#pdf_file = "Aperture Labs Report.pdf"
pdf_file = "Innovant CyberSecurity Report.pdf"
entities = extract_cti_entities(pdf_file)

print("Extracted CTI Entities:")
for e in entities:
    print(e)
# Out:
# Device set to use cuda:0
# Extracted CTI Entities:
# SECTEAM:  Innov, at, ech
# TIME:  January 15,  January 1, 2025,  December 31, 2025
# APT:  Innov, at, ech,  actors
# MAL:  ,
# , ransomware
# TOOL:  SaaS,  multi, -, cloud
# IDTY: nov, at, ech,  employees
# ACT:  phishing,  ,
# , v, ishing campaigns

# %%
pdf_file = "Kaspersky Mobile Cyberthreat Report Q2 2025.pdf"
entities = extract_cti_entities(pdf_file)

print("Extracted CTI Entities:")
for e in entities:
    print(e)
# Out:
# Device set to use cuda:0
# Extracted CTI Entities:
# SECTEAM:  Kaspersky,  Kaspersky,  Kaspersky,  Kaspersky
# URL:  https, ://, secure, list, ., com, /, malware, -, report, -, q, 2, -, 20, 25, -, mobile, -, stat, istics, /, 117, 349, /,
#
# OS:  Android,  Android,  iOS,  Android
# MAL:  mobile banking Trojans,  mobile ransomware Trojans,  Risk, Tool, ., Android, OS, ., Spy, Lo, an,
# , Sp, ark, Kit, ty,  Spark, Cat,  Spark, Kit, ty,
# , DDoS,  Trojan,
# , Trojan, -, DDoS, ., Android, OS, ., Agent, ., a
# FILE:  ,
#
# ACT:  DDoS
